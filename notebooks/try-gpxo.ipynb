# %%
import gpxo

# %%
eg_gpx_file = "../data/apple_health_export/workout-routes/route_2017-07-31_11.57am.gpx"

# %%
track = gpxo.Track(eg_gpx_file)

# %%
track.data
# Out:
# /Users/mjboothaus/code/github/mjboothaus/emmaus-walking-data/.venv/lib/python3.9/site-packages/gpxo/track.py:127: RuntimeWarning: divide by zero encountered in divide
#   vs = 3600 * dd / dt
#                      latitude (°)  longitude (°)  distance (km)  compass (°)  \
# time
# 2017-07-31 00:51:19    -33.857455     151.160325       0.000000   221.821308
# 2017-07-31 00:52:08    -33.857726     151.160033       0.040419   156.067146
# 2017-07-31 00:52:09    -33.857726     151.160052       0.042177    91.813017
# 2017-07-31 00:52:10    -33.857727     151.160071       0.043939    91.813371
# 2017-07-31 00:52:11    -33.857727     151.160087       0.045420    91.813371
# ...                           ...            ...            ...          ...
# 2017-07-31 01:57:28    -33.857680     151.159896       6.816304    84.163400
# 2017-07-31 01:57:29    -33.857678     151.159914       6.817984    84.163400
# 2017-07-31 01:57:30    -33.857677     151.159931       6.819561    85.948196
# ...

# %%
track.map(plot='scatter', c=track.elevation, cmap='plasma')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 track.map(plot='scatter', c=track.elevation, cmap='plasma')
#
# File ~/code/github/mjboothaus/emmaus-walking-data/.venv/lib/python3.9/site-packages/gpxo/track.py:271, in Track.map(self, map_type, embed, ax, size, plot, **kwargs)
#     269     leaflet = mplleaflet.display(**parameters)
#     270 else:
# --> 271     leaflet = mplleaflet.show(**parameters)
#     273 return leaflet
#
# File ~/code/github/mjboothaus/emmaus-walking-data/.venv/lib/python3.9/site-packages/mplleaflet/_display.py:180, in show(fig, path, **kwargs)
#     178 fullpath = os.path.abspath(path)
#     179 with open(fullpath, 'w') as f:
# --> 180     save_html(fig, fileobj=f, **kwargs)
#     181 webbrowser.open('file://' + fullpath)
#
# ...
